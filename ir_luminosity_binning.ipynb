# %%
from cataloging_classes import *

# %%
from SDSSWrapper import SDSS
# Out:
# z,sky_z
# 17.38438,26.25013
#
# 1.472463942246084e+35

# %%
full_cat = SNeCatalogue('general')

# %%
full_cat.generate_dataframe()

# %%
full_cat.dataframe
# Out:
#          cid    peak_ra  peak_decl  nepoch official_name   type_dr  \
# 0        679 -32.565022   0.657569       3        2005eh   Unknown
# 1        680 -32.444595   0.842584      21            \N  Variable
# 2        682 -28.760530   0.845158       2            \N   Unknown
# 3        685 -22.176727  -0.882037      14            \N     pSNII
# 4        688 -16.828396  -0.962902       4            \N   Unknown
# 5        689 -14.685408  -0.866253      15            \N  Variable
# 6        691 -30.270592  -0.498538       9            \N   Unknown
# 7        692  -8.928903  -0.945665      18            \N  Variable
# 8        694 -29.845367  -0.623472      22            \N   Unknown
# 9        695  -7.036626  -0.963772       3            \N  Variable
# 10       696  -5.819952  -1.020436       6            \N     pSNIa
# 11       697 -24.997570  -0.626145       8            \N   Unknown
# 12       698 -24.697414  -0.554336      17            \N  Variable
# ...
